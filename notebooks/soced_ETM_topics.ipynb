# %%
__author__ = "Jon Ball"
__version__ = "Summer 2022"

# %% [markdown]
# Code credit to Espoir Murhabazi and Adji Dieng: https://github.com/adjidieng/ETM/blob/master/main.py

# %%
import os

# %%
with open("soced_embeddings_150epochs.txt", "r") as infile:
    topics = infile.readlines()

# %%
for topic in topics:
    print(topic, "\n")
# Out:
# Topic 0: ['consequences', 'advantage', 'matching', 'authority', 'selection', 'propensity', 'respondents', 'tests', 'bias', 'score', 'degrees', 'advantages', 'mismatch', 'compensatory', 'assessments', 'standards', 'central', 'selectivity', 'range']
#
#
# Topic 1: ['students', 'achievement', 'academic', 'teachers', 'learning', 'mathematics', 'lower', 'performance', 'levels', 'grades', 'english', 'school', 'experiences', 'gains', 'related', 'schools', 'low', 'classroom', 'science']
#
#
# Topic 2: ['students', 'educational', 'school', 'schools', 'academic', 'education', 'student', 'college', 'performance', 'social', 'differences', 'class', 'effects', 'show', 'outcomes', 'examined', 'minority', 'time', 'increased']
#
#
# Topic 3: ['children', 'parents', 'parental', 'families', 'involvement', 'family', 'mothers', 'resources', 'child', 'parenting', 'activities', 'cognitive', 'friends', 'poverty', 'parent', 'siblings', 'homework', 'investment', 'marriage']
#
#
# ...
