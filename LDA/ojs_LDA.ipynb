# %%
from sklearn.decomposition import LatentDirichletAllocation as LDA
from sklearn.feature_extraction.text import CountVectorizer
from nltk.tokenize import word_tokenize
import numpy as np
import time

# %%
with open("../stops.txt", "r") as infile:
    stops = [line.strip() for line in infile.readlines()]
stops.extend(["i", "ii", "iii", "iv", "v", "vi", "vii", "viii", "ix", "x"])

# %%
vec = CountVectorizer(
    max_df=0.7, min_df=30, tokenizer=word_tokenize, stop_words=stops)

# %% [markdown]
# *********************

# %%
with open("ojs10k.txt", "r") as infile:
    ojs = [line.lower().strip() for line in infile.readlines()]

# %%
matrix10k = vec.fit_transform(ojs)

# %%
div_scores = []
ppl_scores = []
for epoch in [51]:
    tock = time.time()
    model = LDA(n_components=50, random_state=100, max_iter=epoch)
    model.fit_transform(matrix10k)
    compnorm = model.components_ / model.components_.sum(axis=1)[:, np.newaxis]
    top_words = []
    for comp in compnorm:
        word_idx = np.argsort(comp)[::-1][:25]
        top_words.append(word_idx)
    toparr = np.array(top_words, dtype=object)
    n_unique = len(np.unique(toparr))
    TD = n_unique / (25 * 50)
    ppl = model.perplexity(matrix10k)
    div_scores.append(TD)
    ppl_scores.append(ppl)
    print(f"Topic diversity: {TD}")
    print(f"Perplexity: {ppl}")
    tick = time.time()
    print(f"Time elapsed: {tick-tock}")
    print("\n")
# Out:
# Topic diversity: 0.5848
# Perplexity: 635.3513055739534
# Time elapsed: 18.835319995880127

# %%
print(div_scores)
# Out:
# [0.1792, 0.3424, 0.4448, 0.5032, 0.54, 0.5616, 0.5704, 0.5752, 0.5792, 0.5792, 0.5808, 0.5824, 0.5824, 0.5832, 0.5848, 0.5848, 0.5848, 0.5848, 0.5848, 0.5848, 0.5848, 0.5848, 0.5848, 0.5848, 0.5848, 0.5848, 0.5848, 0.5848, 0.5848, 0.5848, 0.5848, 0.5848, 0.5848, 0.5848, 0.5848, 0.5848, 0.5848, 0.5848, 0.5848, 0.5848, 0.5848, 0.5848, 0.5848, 0.5848, 0.5848, 0.5848, 0.5848, 0.5848, 0.5848]

# %%
print(ppl_scores)
# Out:
# [1638.957043496083, 1084.5247795811815, 874.0653238407803, 769.2024894603917, 713.3436031694742, 678.0442913591781, 656.517590220653, 643.0224567039692, 634.9184720653984, 627.39897376911, 625.0664079276967, 622.4325198701247, 622.2478326228463, 622.8185393802062, 623.5071843224905, 625.0591739513877, 626.0063419588045, 627.2824629990034, 628.267803783191, 629.5548947311705, 630.4741902137304, 631.0598882581356, 631.5434487484998, 631.9050950595386, 632.6861328062639, 632.8913806777184, 632.9022967969017, 633.2593811654409, 633.2033255916316, 633.2579024765824, 633.5899045166253, 633.8454847411685, 634.0308697653455, 634.0322428717282, 633.9605680844026, 634.1362272825982, 634.0668135361599, 633.9708459863779, 634.0995505769522, 634.3280683708138, 634.5653621101097, 634.7809367853109, 634.9253233010514, 634.9505925050368, 634.9927175681447, 635.1303102244185, 635.3523102589699, 635.312725717959, 635.4074651877027]

# %% [markdown]
# *********************

# %%
with open("ojs64k.txt", "r") as infile:
    ojs = [line.lower().strip() for line in infile.readlines()]

# %%
matrix64k = vec.fit_transform(ojs)

# %%
div_scores = []
ppl_scores = []
for epoch in range(1,50):
    tock = time.time()
    model = LDA(n_components=50, random_state=100, max_iter=epoch)
    model.fit_transform(matrix64k)
    compnorm = model.components_ / model.components_.sum(axis=1)[:, np.newaxis]
    top_words = []
    for comp in compnorm:
        word_idx = np.argsort(comp)[::-1][:25]
        top_words.append(word_idx)
    toparr = np.array(top_words, dtype=object)
    n_unique = len(np.unique(toparr))
    TD = n_unique / (25 * 50)
    ppl = model.perplexity(matrix)
    div_scores.append(TD)
    ppl_scores.append(ppl)
    print(f"Topic diversity: {TD}")
    print(f"Perplexity: {ppl}")
    tick = time.time()
    print(f"Time elapsed: {tick-tock}")
    print("\n")
# Out:
# Topic diversity: 0.116
# Perplexity: 2854.761656927356
# Time elapsed: 22.73287081718445
#
#
# Topic diversity: 0.2512
# Perplexity: 2106.3345890359064
# Time elapsed: 25.60282802581787
#
#
# Topic diversity: 0.3912
# Perplexity: 1778.8357824954041
# Time elapsed: 28.48859715461731
#
#
# Topic diversity: 0.508
# Perplexity: 1606.400581765635
# Time elapsed: 31.96041989326477
#
#
# Topic diversity: 0.5904
# Perplexity: 1511.5201508318912
# Time elapsed: 34.738621950149536
#
#
# Topic diversity: 0.6456
# Perplexity: 1459.0277650150788
# Time elapsed: 38.07667779922485
#
#
# Topic diversity: 0.6808
# Perplexity: 1431.6033013105764
# Time elapsed: 41.16506099700928
#
#
# Topic diversity: 0.7032
# Perplexity: 1416.2685547709768
# Time elapsed: 43.74478888511658
#
#
# Topic diversity: 0.728
# Perplexity: 1408.5576251974067
# Time elapsed: 46.61259603500366
#
#
# Topic diversity: 0.7384
# Perplexity: 1406.205034073722
# Time elapsed: 49.16384816169739
#
#
# Topic diversity: 0.756
# Perplexity: 1406.4643615549212
# Time elapsed: 51.60255408287048
#
#
# Topic diversity: 0.7704
# Perplexity: 1407.6394606279985
# Time elapsed: 54.284297943115234
#
#
# Topic diversity: 0.7776
# Perplexity: 1410.5177892588306
# Time elapsed: 57.25727581977844
#
#
# Topic diversity: 0.7848
# Perplexity: 1414.362753229189
# Time elapsed: 59.93710708618164
#
#
# Topic diversity: 0.7944
# Perplexity: 1417.2993211318799
# Time elapsed: 61.92427706718445
#
#
# Topic diversity: 0.8032
# Perplexity: 1419.9731878010516
# Time elapsed: 64.85304594039917
#
#
# Topic diversity: 0.8048
# Perplexity: 1422.6652128558728
# Time elapsed: 67.6860659122467
#
#
# Topic diversity: 0.8056
# Perplexity: 1425.514682126581
# Time elapsed: 70.42953610420227
#
#
# Topic diversity: 0.8072
# Perplexity: 1427.8316576330171
# Time elapsed: 72.61034798622131
#
#
# Topic diversity: 0.8096
# Perplexity: 1431.0212639761044
# Time elapsed: 74.77928400039673
#
#
# Topic diversity: 0.8168
# Perplexity: 1433.25273559608
# Time elapsed: 77.72275519371033
#
#
# Topic diversity: 0.82
# Perplexity: 1436.3587795841634
# Time elapsed: 79.86029171943665
#
#
# Topic diversity: 0.828
# Perplexity: 1438.8979277928431
# Time elapsed: 82.25791883468628
#
#
# Topic diversity: 0.8296
# Perplexity: 1441.5469410068604
# Time elapsed: 85.84123206138611
#
#
# Topic diversity: 0.8328
# Perplexity: 1443.676630160452
# Time elapsed: 88.65299892425537
#
#
# Topic diversity: 0.832
# Perplexity: 1446.2005648210056
# Time elapsed: 90.03669595718384
#
#
# Topic diversity: 0.8336
# Perplexity: 1448.8644146421998
# Time elapsed: 92.1986792087555
#
#
# Topic diversity: 0.836
# Perplexity: 1451.1790541617893
# Time elapsed: 94.68214392662048
#
#
# Topic diversity: 0.8384
# Perplexity: 1453.1658950495312
# Time elapsed: 97.43976402282715
#
#
# Topic diversity: 0.8392
# Perplexity: 1455.1837713161667
# Time elapsed: 98.76966500282288
#
#
# Topic diversity: 0.8376
# Perplexity: 1456.8407769131254
# Time elapsed: 101.362478017807
#
#
# Topic diversity: 0.8384
# Perplexity: 1458.5885162318293
# Time elapsed: 103.6699287891388
#
#
# Topic diversity: 0.8384
# Perplexity: 1459.7558311298499
# Time elapsed: 106.04049777984619
#
#
# Topic diversity: 0.84
# Perplexity: 1460.8798842544784
# Time elapsed: 108.67743110656738
#
#
# Topic diversity: 0.84
# Perplexity: 1461.847440497539
# Time elapsed: 112.17724585533142
#
#
# Topic diversity: 0.8392
# Perplexity: 1462.756891323648
# Time elapsed: 115.29027509689331
#
#
# Topic diversity: 0.84
# Perplexity: 1463.6966689951826
# Time elapsed: 116.84930801391602
#
#
# Topic diversity: 0.8424
# Perplexity: 1464.8198277871593
# Time elapsed: 117.63179993629456
#
#
# Topic diversity: 0.8432
# Perplexity: 1465.7029179149893
# Time elapsed: 120.62068819999695
#
#
# Topic diversity: 0.844
# Perplexity: 1466.4402095492428
# Time elapsed: 121.78018593788147
#
#
# Topic diversity: 0.8432
# Perplexity: 1466.836408338629
# Time elapsed: 124.66766881942749
#
#
# Topic diversity: 0.844
# Perplexity: 1467.2543082779562
# Time elapsed: 127.1231062412262
#
#
# Topic diversity: 0.8456
# Perplexity: 1467.9364410012133
# Time elapsed: 128.47076201438904
#
#
# Topic diversity: 0.8456
# Perplexity: 1468.3716802250503
# Time elapsed: 130.3119170665741
#
#
# Topic diversity: 0.8464
# Perplexity: 1468.8197460034942
# Time elapsed: 133.67936491966248
#
#
# Topic diversity: 0.8456
# Perplexity: 1469.1921249336133
# Time elapsed: 136.25126886367798
#
#
# Topic diversity: 0.8464
# Perplexity: 1469.5866573958026
# Time elapsed: 138.61022996902466
#
#
# Topic diversity: 0.8472
# Perplexity: 1470.1337134523123
# Time elapsed: 142.1820409297943
#
#
# Topic diversity: 0.8472
# Perplexity: 1470.5142186731653
# Time elapsed: 144.27467513084412

# %%
del ojs

# %%
with open("ojs500k.txt", "r") as infile:
    ojs = [line.lower().strip() for line in infile.readlines()]

# %%
# %time matrix500k = vec.fit_transform(ojs)
# Out:
# CPU times: user 35.6 s, sys: 178 ms, total: 35.8 s
# Wall time: 35.8 s

# %%
div_scores = []
ppl_scores = []
for epoch in range(1,50):
    tock = time.time()
    model = LDA(n_components=50, random_state=100, max_iter=epoch)
    model.fit_transform(matrix500k)
    compnorm = model.components_ / model.components_.sum(axis=1)[:, np.newaxis]
    top_words = []
    for comp in compnorm:
        word_idx = np.argsort(comp)[::-1][:25]
        top_words.append(word_idx)
    toparr = np.array(top_words, dtype=object)
    n_unique = len(np.unique(toparr))
    TD = n_unique / (25 * 50)
    ppl = model.perplexity(matrix)
    div_scores.append(TD)
    ppl_scores.append(ppl)
    print(f"Topic diversity: {TD}")
    print(f"Perplexity: {ppl}")
    tick = time.time()
    print(f"Time elapsed: {tick-tock}")
    print("\n")
# Out:
# Topic diversity: 0.104
# Perplexity: 529705.16497336
# Time elapsed: 153.53865504264832
#
#
# Topic diversity: 0.2312
# Perplexity: 357239.77817375556
# Time elapsed: 184.82922911643982
#
#
# Topic diversity: 0.3664
# Perplexity: 262162.3676364781
# Time elapsed: 215.99445390701294
#
#
# Topic diversity: 0.4672
# Perplexity: 210075.25988814034
# Time elapsed: 241.2549111843109
#
#
# Topic diversity: 0.5384
# Perplexity: 178127.94399345573
# Time elapsed: 270.4438371658325
#
#
# Topic diversity: 0.5864
# Perplexity: 158229.79810808485
# Time elapsed: 295.6091718673706
#
#
# Topic diversity: 0.628
# Perplexity: 145298.6883369173
# Time elapsed: 319.11403012275696
#
#
# Topic diversity: 0.656
# Perplexity: 137248.36704476358
# Time elapsed: 344.42570900917053
#
#
# Topic diversity: 0.676
# Perplexity: 132339.08541819896
# Time elapsed: 373.3389058113098
#
#
# Topic diversity: 0.6904
# Perplexity: 128240.7091014212
# Time elapsed: 396.9002482891083
#
#
# Topic diversity: 0.7064
# Perplexity: 125102.84176365162
# Time elapsed: 417.159903049469
#
#
# Topic diversity: 0.7224
# Perplexity: 122800.72058666038
# Time elapsed: 441.69324803352356
#
#
# Topic diversity: 0.732
# Perplexity: 121126.49543107278
# Time elapsed: 464.2903709411621
#
#
# Topic diversity: 0.7408
# Perplexity: 119824.260984731
# Time elapsed: 489.41674065589905
#
#
# Topic diversity: 0.7456
# Perplexity: 118959.23554296845
# Time elapsed: 509.2390170097351
#
#
# Topic diversity: 0.7472
# Perplexity: 118271.89985770587
# Time elapsed: 536.6933450698853
#
#
# Topic diversity: 0.7552
# Perplexity: 117405.57783363378
# Time elapsed: 553.606057882309
#
#
# Topic diversity: 0.7592
# Perplexity: 116624.77884358006
# Time elapsed: 574.9752810001373
#
#
# Topic diversity: 0.7624
# Perplexity: 116017.22963021044
# Time elapsed: 599.8411478996277
#
#
# Topic diversity: 0.768
# Perplexity: 115493.20871774826
# Time elapsed: 625.1038918495178
#
#
# Topic diversity: 0.7688
# Perplexity: 115058.15452598486
# Time elapsed: 641.7079181671143
#
#
# Topic diversity: 0.7712
# Perplexity: 114542.9051164241
# Time elapsed: 663.562497138977
#
#
# Topic diversity: 0.7736
# Perplexity: 114364.53611299909
# Time elapsed: 691.0529131889343
#
#
# Topic diversity: 0.7784
# Perplexity: 114213.955805536
# Time elapsed: 708.7846629619598
#
#
# Topic diversity: 0.7832
# Perplexity: 113873.56567804309
# Time elapsed: 730.1616649627686
#
#
# Topic diversity: 0.7856
# Perplexity: 113619.99548817471
# Time elapsed: 748.7814960479736
#
#
# Topic diversity: 0.7856
# Perplexity: 113482.11808547263
# Time elapsed: 773.9855806827545
#
#
# Topic diversity: 0.7896
# Perplexity: 113145.51707892837
# Time elapsed: 789.2903778553009
#
#
# Topic diversity: 0.792
# Perplexity: 112953.85492940046
# Time elapsed: 818.159166097641
#
#
# Topic diversity: 0.7928
# Perplexity: 112807.26851060646
# Time elapsed: 840.5932011604309
#
#
# Topic diversity: 0.7936
# Perplexity: 112642.37800812886
# Time elapsed: 858.0107152462006
#
#
# Topic diversity: 0.7944
# Perplexity: 112477.73541860063
# Time elapsed: 880.265200138092
#
#
# Topic diversity: 0.7952
# Perplexity: 112290.35613346822
# Time elapsed: 895.2842457294464
#
#
# Topic diversity: 0.7968
# Perplexity: 112189.57879912382
# Time elapsed: 920.323970079422
#
#
# Topic diversity: 0.7992
# Perplexity: 112123.05592636655
# Time elapsed: 938.5466401576996
#
#
# Topic diversity: 0.8024
# Perplexity: 112017.88713414945
# Time elapsed: 959.4862205982208
#
#
# Topic diversity: 0.8032
# Perplexity: 111859.37041045308
# Time elapsed: 978.2800297737122
#
#
# Topic diversity: 0.8072
# Perplexity: 111750.52982795938
# Time elapsed: 1002.1443138122559
#
#
# Topic diversity: 0.8072
# Perplexity: 111679.33235719959
# Time elapsed: 1027.1714251041412
#
#
# Topic diversity: 0.8072
# Perplexity: 111607.69725627739
# Time elapsed: 1039.3332719802856
#
#
# Topic diversity: 0.808
# Perplexity: 111628.00969065951
# Time elapsed: 1064.231614112854
#
#
# Topic diversity: 0.8072
# Perplexity: 111479.31463650324
# Time elapsed: 1084.7199938297272
#
#
# Topic diversity: 0.8104
# Perplexity: 111326.53983971805
# Time elapsed: 1112.1976330280304
#
#
# Topic diversity: 0.8104
# Perplexity: 111172.70966825036
# Time elapsed: 1163.1289958953857
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [14], line 6
#       4 tock = time.time()
#       5 model = LDA(n_components=50, random_state=100, max_iter=epoch)
# ----> 6 model.fit_transform(matrix500k)
#       7 compnorm = model.components_ / model.components_.sum(axis=1)[:, np.newaxis]
#       8 top_words = []
#
# File ~/opt/anaconda3/envs/edtm/lib/python3.9/site-packages/sklearn/base.py:867, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     863 # non-optimized default implementation; override when a better
#     864 # method is possible for a given clustering algorithm
#     865 if y is None:
#     866     # fit method of arity 1 (unsupervised transformation)
# --> 867     return self.fit(X, **fit_params).transform(X)
#     868 else:
#     869     # fit method of arity 2 (supervised transformation)
#     870     return self.fit(X, y, **fit_params).transform(X)
#
# File ~/opt/anaconda3/envs/edtm/lib/python3.9/site-packages/sklearn/decomposition/_lda.py:640, in LatentDirichletAllocation.fit(self, X, y)
#     632         self._em_step(
#     633             X[idx_slice, :],
#     634             total_samples=n_samples,
#     635             batch_update=False,
#     636             parallel=parallel,
#     637         )
#     638 else:
#     639     # batch update
# --> 640     self._em_step(
#     641         X, total_samples=n_samples, batch_update=True, parallel=parallel
#     642     )
#     644 # check perplexity
#     645 if evaluate_every > 0 and (i + 1) % evaluate_every == 0:
#
# File ~/opt/anaconda3/envs/edtm/lib/python3.9/site-packages/sklearn/decomposition/_lda.py:503, in LatentDirichletAllocation._em_step(self, X, total_samples, batch_update, parallel)
#     476 """EM update for 1 iteration.
#     477
#     478 update `_component` by batch VB or online VB.
#    (...)
#     499     Unnormalized document topic distribution.
#     500 """
#     502 # E-step
# --> 503 _, suff_stats = self._e_step(
#     504     X, cal_sstats=True, random_init=True, parallel=parallel
#     505 )
#     507 # M-step
#     508 if batch_update:
#
# File ~/opt/anaconda3/envs/edtm/lib/python3.9/site-packages/sklearn/decomposition/_lda.py:446, in LatentDirichletAllocation._e_step(self, X, cal_sstats, random_init, parallel)
#     444 if parallel is None:
#     445     parallel = Parallel(n_jobs=n_jobs, verbose=max(0, self.verbose - 1))
# --> 446 results = parallel(
#     447     delayed(_update_doc_distribution)(
#     448         X[idx_slice, :],
#     449         self.exp_dirichlet_component_,
#     450         self.doc_topic_prior_,
#     451         self.max_doc_update_iter,
#     452         self.mean_change_tol,
#     453         cal_sstats,
#     454         random_state,
#     455     )
#     456     for idx_slice in gen_even_slices(X.shape[0], n_jobs)
#     457 )
#     459 # merge result
#     460 doc_topics, sstats_list = zip(*results)
#
# File ~/opt/anaconda3/envs/edtm/lib/python3.9/site-packages/joblib/parallel.py:1085, in Parallel.__call__(self, iterable)
#    1076 try:
#    1077     # Only set self._iterating to True if at least a batch
#    1078     # was dispatched. In particular this covers the edge
#    (...)
#    1082     # was very quick and its callback already dispatched all the
#    1083     # remaining jobs.
#    1084     self._iterating = False
# -> 1085     if self.dispatch_one_batch(iterator):
#    1086         self._iterating = self._original_iterator is not None
#    1088     while self.dispatch_one_batch(iterator):
#
# File ~/opt/anaconda3/envs/edtm/lib/python3.9/site-packages/joblib/parallel.py:901, in Parallel.dispatch_one_batch(self, iterator)
#     899     return False
#     900 else:
# --> 901     self._dispatch(tasks)
#     902     return True
#
# File ~/opt/anaconda3/envs/edtm/lib/python3.9/site-packages/joblib/parallel.py:819, in Parallel._dispatch(self, batch)
#     817 with self._lock:
#     818     job_idx = len(self._jobs)
# --> 819     job = self._backend.apply_async(batch, callback=cb)
#     820     # A job can complete so quickly than its callback is
#     821     # called before we get here, causing self._jobs to
#     822     # grow. To ensure correct results ordering, .insert is
#     823     # used (rather than .append) in the following line
#     824     self._jobs.insert(job_idx, job)
#
# File ~/opt/anaconda3/envs/edtm/lib/python3.9/site-packages/joblib/_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File ~/opt/anaconda3/envs/edtm/lib/python3.9/site-packages/joblib/_parallel_backends.py:597, in ImmediateResult.__init__(self, batch)
#     594 def __init__(self, batch):
#     595     # Don't delay the application, to avoid keeping the input
#     596     # arguments in memory
# --> 597     self.results = batch()
#
# File ~/opt/anaconda3/envs/edtm/lib/python3.9/site-packages/joblib/parallel.py:288, in BatchedCalls.__call__(self)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File ~/opt/anaconda3/envs/edtm/lib/python3.9/site-packages/joblib/parallel.py:288, in <listcomp>(.0)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File ~/opt/anaconda3/envs/edtm/lib/python3.9/site-packages/sklearn/utils/fixes.py:117, in _FuncWrapper.__call__(self, *args, **kwargs)
#     115 def __call__(self, *args, **kwargs):
#     116     with config_context(**self.config):
# --> 117         return self.function(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/edtm/lib/python3.9/site-packages/sklearn/decomposition/_lda.py:88, in _update_doc_distribution(X, exp_topic_word_distr, doc_topic_prior, max_doc_update_iter, mean_change_tol, cal_sstats, random_state)
#      85 n_topics = exp_topic_word_distr.shape[0]
#      87 if random_state:
# ---> 88     doc_topic_distr = random_state.gamma(100.0, 0.01, (n_samples, n_topics))
#      89 else:
#      90     doc_topic_distr = np.ones((n_samples, n_topics))
#
# KeyboardInterrupt:

# %%
print(div_scores)
# Out:
# [0.104, 0.2312, 0.3664, 0.4672, 0.5384, 0.5864, 0.628, 0.656, 0.676, 0.6904, 0.7064, 0.7224, 0.732, 0.7408, 0.7456, 0.7472, 0.7552, 0.7592, 0.7624, 0.768, 0.7688, 0.7712, 0.7736, 0.7784, 0.7832, 0.7856, 0.7856, 0.7896, 0.792, 0.7928, 0.7936, 0.7944, 0.7952, 0.7968, 0.7992, 0.8024, 0.8032, 0.8072, 0.8072, 0.8072, 0.808, 0.8072, 0.8104, 0.8104]

# %%
print(ppl_scores)
# Out:
# [529705.16497336, 357239.77817375556, 262162.3676364781, 210075.25988814034, 178127.94399345573, 158229.79810808485, 145298.6883369173, 137248.36704476358, 132339.08541819896, 128240.7091014212, 125102.84176365162, 122800.72058666038, 121126.49543107278, 119824.260984731, 118959.23554296845, 118271.89985770587, 117405.57783363378, 116624.77884358006, 116017.22963021044, 115493.20871774826, 115058.15452598486, 114542.9051164241, 114364.53611299909, 114213.955805536, 113873.56567804309, 113619.99548817471, 113482.11808547263, 113145.51707892837, 112953.85492940046, 112807.26851060646, 112642.37800812886, 112477.73541860063, 112290.35613346822, 112189.57879912382, 112123.05592636655, 112017.88713414945, 111859.37041045308, 111750.52982795938, 111679.33235719959, 111607.69725627739, 111628.00969065951, 111479.31463650324, 111326.53983971805, 111172.70966825036]

# %%
del ojs

# %% [markdown]
# *************************************

# %%
with open("ojs1M.txt", "r") as infile:
    ojs = [line.lower().strip() for line in infile.readlines()]

# %%
# %time matrix1M = vec.fit_transform(ojs)
# Out:
# CPU times: user 1min 10s, sys: 420 ms, total: 1min 11s
# Wall time: 1min 11s

# %%
div_scores = []
ppl_scores = []
for epoch in range(1,50):
    tock = time.time()
    model = LDA(n_components=50, random_state=100, max_iter=epoch)
    model.fit_transform(matrix1M)
    compnorm = model.components_ / model.components_.sum(axis=1)[:, np.newaxis]
    top_words = []
    for comp in compnorm:
        word_idx = np.argsort(comp)[::-1][:25]
        top_words.append(word_idx)
    toparr = np.array(top_words, dtype=object)
    n_unique = len(np.unique(toparr))
    TD = n_unique / (25 * 50)
    ppl = model.perplexity(matrix1M)
    div_scores.append(TD)
    ppl_scores.append(ppl)
    print(f"Topic diversity: {TD}")
    print(f"Perplexity: {ppl}")
    tick = time.time()
    print(f"Time elapsed: {tick-tock}")
    print("\n")
# Out:
# Topic diversity: 0.1008
# Perplexity: 3510.1443782144133
# Time elapsed: 413.35098099708557
#
#
# Topic diversity: 0.2344
# Perplexity: 2695.6644189751164
# Time elapsed: 457.41803884506226

# %%
x = (div_scores, ppl_scores)
